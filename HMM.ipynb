# %%
import numpy as np
import matplotlib.pyplot as plt
import impnb
import pandas as pd
from hmmlearn import hmm
Logs=pd.read_pickle('BehaviorLog/rat26to38.pkl')
sample=Logs[26]['action'][0]

# %%
model=hmm.GMMHMM(n_components=2,n_iter=100)
model.fit(sample.reshape(-1, 1))
# Out:
# GMMHMM(algorithm='viterbi', covariance_type='diag',
#     covars_prior=array([[[-1.5]],
#
#        [[-1.5]]]),
#     covars_weight=array([[[0.]],
#
#        [[0.]]]), init_params='stmcw',
#     means_prior=array([[[0.]],
#
#        [[0.]]]),
#     means_weight=array([[0.],
#        [0.]]), min_covar=0.001,
#     n_components=2, n_iter=100, n_mix=1, params='stmcw', random_state=None,
#     startprob_prior=1.0, tol=0.01, transmat_prior=1.0, verbose=False,
#     weights_prior=array([[1.],
#        [1.]]))

# %%
pred=model.predict(sample)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-15e227b6c310> in <module>
# ----> 1 pred=model.predict(sample)
#
# ~/anaconda3/lib/python3.7/site-packages/hmmlearn/base.py in predict(self, X, lengths)
#     373             Labels for each sample from ``X``.
#     374         """
# --> 375         _, state_sequence = self.decode(X, lengths)
#     376         return state_sequence
#     377
#
# ~/anaconda3/lib/python3.7/site-packages/hmmlearn/base.py in decode(self, X, lengths, algorithm)
#     333         """
#     334         check_is_fitted(self, "startprob_")
# --> 335         self._check()
#     336
#     337         algorithm = algorithm or self.algorithm
#
# ~/anaconda3/lib/python3.7/site-packages/hmmlearn/hmm.py in _check(self)
#     757             if np.any(self.covars_ <= 0):
# ...

# %%
plt.plot(sample)
plt.plot(pred)

# %%
sample.shape
# Out:
# (294,)

# %%
sum(X.round()==1)
# Out:
# array([113])

# %%
model.get_stationary_distribution()
# Out:
# array([0.19544346, 0.41366961, 0.19544346, 0.19544346])
