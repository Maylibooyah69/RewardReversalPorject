# %%
#On OS X, you can install ffmpeg via `brew install ffmpeg'
import numpy as np
import io
import base64
from mpl_toolkits import mplot3d
from IPython.display import HTML
import matplotlib.pyplot as plt
import functools
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %config IPCompleter.greedy=True

# %%
A=np.array([1,2])
np.min(A)
# Out:
# 1

# %%
def Qupdate(Q,alpha):
    return (1-alpha)*Q+alpha

# %%
Qupdate(0.1,1)
# Out:
# 1.0

# %% [markdown]
# # Q-learning memory

# %%
def Qtick(Q0,alpha,r=1):
    return (1-alpha)*Q0+alpha*r

def renum(X,Y):
    return 0.8+X*0

# %%
x = np.linspace(0, 1, 30)
y = np.linspace(0, 0.8, 30)
X, Y = np.meshgrid(x, y)
Z = renum(X, Y)
Z
# Out:
# array([[0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8,
#         0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8,
#         0.8, 0.8, 0.8, 0.8],
#        [0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8,
#         0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8,
#         0.8, 0.8, 0.8, 0.8],
#        [0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8,
#         0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8,
#         0.8, 0.8, 0.8, 0.8],
#        [0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8,
#         0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8,
#         0.8, 0.8, 0.8, 0.8],
#        [0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8,
#         0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8,
#         0.8, 0.8, 0.8, 0.8],
#        [0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8,
# ...

# %%
def rotcontour(Xang,Yang=45):
    x = np.linspace(0, 1, 30)
    y = np.linspace(0, 0.8, 30)
    X, Y = np.meshgrid(x, y)
    Z = Qtick(X, Y)
    fig = plt.figure()
    ax = plt.axes(projection='3d')
    Z0=renum(X,Y)
    ax.contour3D(X,Y,Z,50,cmap='binary')
    ax.plot_surface(X, Y, Z0, rstride=1, cstride=1,
                cmap='binary', edgecolor='none');
    ax.view_init(Xang,Yang) #forward-backward,left and right
    ax.set_xlabel('Q0')
    ax.set_ylabel('alpha')
    ax.set_zlabel('Q1');

# %%
interact(rotcontour,Xang=90)
# Out:
# interactive(children=(IntSlider(value=90, description='Xang', max=270, min=-90), IntSlider(value=45, descripti…
# <function __main__.rotcontour(Xang, Yang=45)>
